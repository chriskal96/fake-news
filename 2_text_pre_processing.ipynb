# %%
import pandas as pd
from nltk.tokenize import RegexpTokenizer, word_tokenize, TweetTokenizer
from nltk import FreqDist
import re
import string
from nltk.corpus import stopwords

# %%
df = pd.read_csv('df_clean.csv')
df
# Out:
#        Unnamed: 0                                              title  \
# 0               0   Donald Trump Sends Out Embarrassing New Year’...
# 1               1   Drunk Bragging Trump Staffer Started Russian ...
# 2               2   Sheriff David Clarke Becomes An Internet Joke...
# 3               3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4               4   Pope Francis Just Called Out Donald Trump Dur...
# ...           ...                                                ...
# 38633       38639  'Fully committed' NATO backs new U.S. approach...
# 38634       38640  LexisNexis withdrew two products from Chinese ...
# 38635       38641  Minsk cultural hub becomes haven from authorities
# 38636       38642  Vatican upbeat on possibility of Pope Francis ...
# 38637       38643  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 0      Donald Trump just couldn t wish all Americans ...       News
# 1      House Intelligence Committee Chairman Devin Nu...       News
# 2      On Friday, it was revealed that former Milwauk...       News
# 3      On Christmas day, Donald Trump announced that ...       News
# 4      Pope Francis used his annual Christmas Day mes...       News
# ...                                                  ...        ...
# 38633  BRUSSELS (Reuters) - NATO allies on Tuesday we...  worldnews
# 38634  LONDON (Reuters) - LexisNexis, a provider of l...  worldnews
# 38635  MINSK (Reuters) - In the shadow of disused Sov...  worldnews
# 38636  MOSCOW (Reuters) - Vatican Secretary of State ...  worldnews
# 38637  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  worldnews
#
#              date label  caps_in_title
# 0      2017-12-31  fake             11
# 1      2017-12-31  fake              8
# 2      2017-12-30  fake             15
# 3      2017-12-29  fake             19
# 4      2017-12-25  fake             11
# ...           ...   ...            ...
# 38633  2017-08-22  true              8
# 38634  2017-08-22  true              3
# 38635  2017-08-22  true              1
# 38636  2017-08-22  true              4
# 38637  2017-08-22  true              2
#
# [38638 rows x 7 columns]

# %% [markdown]
# #### Clean Title and Text Data

# %%
def concat_lists_of_strings(df, column):
    """Concatenate a series of lists of strings from a column in a dataframe"""
    return [x for list_ in df[column].values for x in list_]

# %%
def find_strings(string_, regex):
    """Find and Return a list of URLs in the input string"""
    list_ = re.findall(regex, string_)
    return [s[0] for s in list_]

# %%
def freq_dist_of_col(df, col):
    """Return a Frequency Distribution of a column"""
    corpus_tokens = concat_lists_of_strings(df, col)
    corpus_freq_dist = FreqDist(corpus_tokens)
    print(f'The number of unique tokens in the corpus is {len(corpus_freq_dist)}')
    return corpus_freq_dist

# %%
def review_freq_dis(df, col, n):
    """
    Create a Frequency Distribution of a column of a dataframe and display
    the n most common tokens.
    """
    corpus_freq_dist = freq_dist_of_col(df, col)
    display(corpus_freq_dist.most_common(n))

# %%
def remove_punctuation(word_list, punctuation_list):
    """Remove punctuation tokens from a list of tokens"""
    return [w for w in word_list if w not in punctuation_list]

# %%
def remove_single_characters(word_list, exception_list):
    """Remove all the single characters, except those on the exception list"""
    return [w for w in word_list if (len(w) > 1 or w in exception_list)]

# %%
def remove_words(word_list, words_to_remove):
    """Remove all the words in the words_to_remove list from the words_list"""
    return [w for w in word_list if w not in words_to_remove]

# %% [markdown]
# #### Rough look at token frequency distribution

# %%
tknzr = RegexpTokenizer(r'\w+|\$[\d\.]+|\([@\w\d]+\)')

# %%
df['text_tokens'] = df['text'].apply(tknzr.tokenize)

# %%
corpus_freq_dist = freq_dist_of_col(df, 'text_tokens')
# Out:
# The number of unique tokens in the corpus is 152402

# %%
corpus_freq_dist.most_common(150)
# Out:
# [('the', 771208),
#  ('to', 457849),
#  ('of', 372801),
#  ('a', 339364),
#  ('and', 336802),
#  ('in', 282041),
#  ('s', 198810),
#  ('that', 195661),
#  ('on', 162850),
#  ('for', 144241),
#  ('is', 138935),
#  ('said', 122504),
#  ('Trump', 121295),
#  ('with', 98710),
#  ('The', 98576),
#  ('was', 96440),
#  ('he', 95085),
#  ('it', 88450),
#  ('as', 82843),
#  ('his', 80861),
#  ('by', 79953),
#  ('has', 78027),
#  ('be', 71600),
#  ('have', 70857),
#  ('not', 68321),
#  ('from', 67728),
#  ('are', 60493),
#  ('at', 59290),
#  ('who', 58081),
#  ('an', 56078),
#  ('I', 51915),
#  ('this', 50639),
#  ('U', 50227),
#  ('would', 49247),
#  ('S', 47546),
#  ('they', 47357),
#  ('t', 44464),
#  ('will', 42664),
#  ('about', 41975),
#  ('had', 40196),
#  ('their', 38467),
#  ('been', 36588),
#  ('but', 36488),
#  ('people', 34367),
#  ('were', 34078),
#  ('which', 33115),
#  ('or', 32819),
#  ('we', 32590),
#  ('more', 31681),
#  ('you', 31398),
#  ('President', 31135),
#  ('out', 29155),
#  ('her', 28292),
#  ('after', 28290),
#  ('one', 27682),
#  ('all', 26913),
#  ('its', 26839),
#  ('also', 26472),
#  ('up', 26251),
#  ('Donald', 25600),
#  ('It', 25276),
#  ('she', 24712),
#  ('Republican', 24000),
#  ('over', 23954),
#  ('government', 23765),
#  ('what', 23552),
#  ('He', 22992),
#  ('House', 22907),
#  ('Clinton', 22870),
#  ('when', 22753),
#  ('him', 22674),
#  ('Obama', 22570),
#  ('can', 22400),
#  ('if', 21886),
#  ('than', 21873),
#  ('year', 21555),
#  ('no', 21475),
#  ('In', 21304),
#  ('could', 21059),
#  ('(Reuters)', 21032),
#  ('told', 20633),
#  ('United', 20576),
#  ('other', 20479),
#  ('our', 20175),
#  ('there', 19844),
#  ('just', 19406),
#  ('into', 19366),
#  ('state', 19044),
#  ('campaign', 18977),
#  ('We', 18801),
#  ('so', 18785),
#  ('against', 18700),
#  ('them', 18651),
#  ('like', 18215),
#  ('some', 18203),
#  ('do', 18045),
#  ('election', 17912),
#  ('because', 17423),
#  ('two', 17418),
#  ('president', 17360),
#  ('time', 17312),
#  ('States', 17239),
#  ('any', 16961),
#  ('A', 16910),
#  ('last', 16901),
#  ('But', 16425),
#  ('country', 15724),
#  ('only', 15361),
#  ('should', 14690),
#  ('new', 14669),
#  ('now', 14664),
#  ('former', 14530),
#  ('being', 14364),
#  ('White', 14235),
#  ('years', 14215),
#  ('did', 14167),
#  ('first', 14126),
#  ('re', 13919),
#  ('This', 13867),
#  ('how', 13836),
#  ('before', 13517),
#  ('even', 13463),
#  ('say', 13387),
#  ('percent', 13372),
#  ('Republicans', 13323),
#  ('made', 13128),
#  ('American', 12960),
#  ('Hillary', 12585),
#  ('law', 12494),
#  ('most', 12464),
#  ('political', 12427),
#  ('during', 12341),
#  ('get', 12316),
#  ('Russia', 12293),
#  ('many', 12270),
#  ('party', 12237),
#  ('going', 12185),
#  ('make', 12055),
#  ('presidential', 11883),
#  ('right', 11867),
#  ('Senate', 11780),
#  ('where', 11577),
#  ('media', 11558),
#  ('week', 11522),
#  ('called', 11514),
#  ('since', 11497),
#  ('very', 11492),
#  ('those', 11462),
#  ('back', 11355),
#  ('New', 11354)]

# %%
len([w for w in corpus_freq_dist.most_common() if w[1] == 1]) #How many tokens were only used once?
# Out:
# 67886

# %% [markdown]
# #### Investigate URLs in the text

# %%
URL_REGEX = r"(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:'\".,<>?«»“”‘’]))"

# %%
df['text_urls'] = df['text'].apply(lambda x: find_strings(x, URL_REGEX))

# %%
urls_in_text = concat_lists_of_strings(df, 'text_urls')

# %%
urls_in_text
# Out:
# ['pic.twitter.com/4FPAe2KypA',
#  'pic.twitter.com/XtZW5PdU2b',
#  'pic.twitter.com/T2NY2psHCR',
#  'https://t.co/zcbyc4Wp5b',
#  'pic.twitter.com/fWfXsZupxy',
#  '2017pic.twitter.com/ymsOBLjfxU',
#  'pic.twitter.com/dWr5k8ZEZV',
#  'pic.twitter.com/ulCFddhkdy',
#  'https://t.co/Fg7VacxRtJ',
#  'pic.twitter.com/5gEMcjQTbH',
#  'https://t.co/zrWpyMXRcz',
#  'pic.twitter.com/wiQSQNNzw0',
#  'https://t.co/dkhw0AlHB4',
#  'pic.twitter.com/oaZDT126B3',
#  'https://t.co/ayBlGmk65Z',
#  'pic.twitter.com/Z7dmyQ5smy',
#  'pic.twitter.com/8TKtrMqRa1',
#  'pic.twitter.com/hIxs3DciO8',
#  'pic.twitter.com/E5bmcI83mU',
#  'pic.twitter.com/a45En9Jwys',
#  'pic.twitter.com/yLCBmhpNvG',
#  'pic.twitter.com/3vMZUTEylx',
#  'https://t.co/XrOvu32EV8',
#  'pic.twitter.com/eMP9UX1bM8',
#  'pic.twitter.com/XViyKFQCET',
#  'https://t.co/HFYJRkefJ1',
#  'https://t.co/65FhbQHuV4',
#  'https://t.co/7lHYkIloyz',
#  'https://t.co/g8SwgAKtfH',
#  'https://t.co/9lCqpYujKN',
#  'pic.twitter.com/NXEX9rGBgu',
#  'pic.twitter.com/QePW9FtbSh',
#  'pic.twitter.com/mUbKCIWGxB',
#  'pic.twitter.com/wFgDkvzEhT',
#  'pic.twitter.com/I2a1Uz5DGK',
#  'https://t.co/SIoAxatCjp',
#  'https://t.co/XpDJYFZjzn',
#  'pic.twitter.com/exQIAjZJ05',
#  'pic.twitter.com/NJ3evTw0mw',
#  'pic.twitter.com/NmuRm5MgMz',
#  'pic.twitter.com/Qesftp1u28',
#  'pic.twitter.com/JajOLBYqc6',
#  '2017pic.twitter.com/zB2kijzXk1',
#  'pic.twitter.com/JZMTaEYdxQ',
#  'pic.twitter.com/KQfW7bOyk1',
#  'https://t.co/gWl6KsAaLE',
#  'https://t.co/TSb8B9Oj1B',
#  'https://t.co/SIoAxatCjp',
#  'pic.twitter.com/Vu50IDUB3m',
#  'pic.twitter.com/Ab8AMi0UxB',
#  'pic.twitter.com/OZ1ZiBrMNL',
#  'https://t.co/c6Wtd0TfzW',
#  'pic.twitter.com/L1o5CjJXrQ',
#  'pic.twitter.com/BiQfQkTra9',
#  'https://t.co/6c0yV1lupe',
#  'pic.twitter.com/wL9en474YQ',
#  'pic.twitter.com/6hKUGGIYRm',
#  'pic.twitter.com/6dUnchk8tC',
#  'pic.twitter.com/mb18VywW3L',
ect.facebook.net/en_US/sdk.js#xfbml=1&version=v2.3',
#  'pic.twitter.com/uGXCchcW08',
#  'https://t.co/vTf5osrr15',
#  'https://t.co/6ZS2qI2Pd1',
#  'https://t.co/8VI6UO3GZq',
#  'https://t.co/UYUOR30xnr',
#  'https://t.co/6wf4pClEvr',
#  'https://t.co/TPXgutpkZq',
#  'https://t.co/n24XrbDDx6',
#  'https://t.co/IyfFbKVUKU',
#  'pic.twitter.com/DIk6kw5akj',
#  'pic.twitter.com/y7dwtWTQ4G',
#  'https://t.co/gY7pcfD4yj',
#  'pic.twitter.com/ctwy2si9A7',
#  '2017pic.twitter.com/EFiwlk8Q15',
#  'connect.facebook.net/en_US/sdk.js#xfbml=1&version=v2.3',
#  'https://t.co/ZifZ6pZa4V',
#  'https://t.co/wgNDVuy29D',
#  'https://twitter.com/realDonaldTrump/status/874619861019840512',
#  'pic.twitter.com/4qN3thefAq',
#  'https://t.co/WTJjFuSSuG',
#  'https://t.co/lEVlBR8LI6',
#  'pic.twitter.com/mKrU63KWmA',
#  'https://t.co/nSt1MGGM2U',
#  'https://t.co/gHaHEhxGCU',
#  'https://t.co/yBo6NljTkP',
#  'https://t.co/yBo6NlBucn',
#  'https://t.co/5e88BJyqnz',
#  'https://t.co/aIRllxNLQA',
#  'https://t.co/4nxLipafWO',
#  'pic.twitter.com/bPZ2UtRkxW',
#  'pic.twitter.com/JuPSprEUkM',
#  'pic.twitter.com/ocE1xhEAac',
#  'pic.twitter.com/j9QFGrXquN',
#  'pic.twitter.com/PfRtq6ARhm',
#  'pic.twitter.com/o5KWp9xHB2',
#  'pic.twitter.com/3fc4WaHIVI',
#  'https://t.co/JfOmLLBJCn',
#  'pic.twitter.com/IPEwbLJFlq',
#  'https://t.co/mBFn4aCGi4',
#  'pic.twitter.com/0ea0moLb5g',
#  'https://t.co/MehpABcH5z',
#  'pic.twitter.com/kWzx1wKDmz',
#  'pic.twitter.com/jQTQYBFpdb',
#  'https://t.co/TkUmw3EzTR',
#  'https://t.co/secLdw2Xjp',
#  '2017pic.twitter.com/UDs6wOIkQo',
#  'pic.twitter.com/SbqMQodmPR',
#  '2017pic.twitter.com/mrnJEuKiEb',
#  ...]

# %%
len(urls_in_text)
# Out:
# 9648

# %% [markdown]
# The URLs look to all be links to Twitter images, probably profile photos.
# We think it would be of more potential significance if there are links in a story rather than what that link is, so we will convert all the urls to the placeholder {link}.

# %%
df['clean_text'] = df['text'].apply(lambda x: re.sub(URL_REGEX, '{link}', x))

# %%
df.head()
# Out:
#    Unnamed: 0                                              title  \
# 0           0   Donald Trump Sends Out Embarrassing New Year’...
# 1           1   Drunk Bragging Trump Staffer Started Russian ...
# 2           2   Sheriff David Clarke Becomes An Internet Joke...
# 3           3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4           4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject        date  \
# 0  Donald Trump just couldn t wish all Americans ...    News  2017-12-31
# 1  House Intelligence Committee Chairman Devin Nu...    News  2017-12-31
# 2  On Friday, it was revealed that former Milwauk...    News  2017-12-30
# 3  On Christmas day, Donald Trump announced that ...    News  2017-12-29
# 4  Pope Francis used his annual Christmas Day mes...    News  2017-12-25
#
#   label  caps_in_title                                        text_tokens  \
# 0  fake             11  [Donald, Trump, just, couldn, t, wish, all, Am...
# 1  fake              8  [House, Intelligence, Committee, Chairman, Dev...
# 2  fake             15  [On, Friday, it, was, revealed, that, former, ...
# 3  fake             19  [On, Christmas, day, Donald, Trump, announced,...
# 4  fake             11  [Pope, Francis, used, his, annual, Christmas, ...
#
#                                            text_urls  \
# 0                       [pic.twitter.com/4FPAe2KypA]
# 1                                                 []
# 2  [pic.twitter.com/XtZW5PdU2b, pic.twitter.com/T...
# 3  [https://t.co/Fg7VacxRtJ, pic.twitter.com/5gEM...
# 4                                                 []
#
#                                           clean_text
# 0  Donald Trump just couldn t wish all Americans ...
# 1  House Intelligence Committee Chairman Devin Nu...
# 2  On Friday, it was revealed that former Milwauk...
# 3  On Christmas day, Donald Trump announced that ...
# 4  Pope Francis used his annual Christmas Day mes...

# %% [markdown]
# #### Investigate URLs in title

# %%
df['title_urls'] = df['title'].apply(lambda x: find_strings(x, URL_REGEX))
urls_in_titles = concat_lists_of_strings(df, 'title_urls')
urls_in_titles
# Out:
# []

# %% [markdown]
# There are no URLs in the title field

# %% [markdown]
# #### Investigate Twitter handles in Text

# %%
TWITTER_HANDLE_REGEX = r'(?<=^|(?<=[^\w]))(@\w{1,15})\b'

# %%
df['twitter_handles'] = df['clean_text'].apply(lambda x: re.findall(TWITTER_HANDLE_REGEX, x))

# %%
twitter_handles = concat_lists_of_strings(df, 'twitter_handles')

# %%
twitter_freq_dist = FreqDist(twitter_handles)

# %%
twitter_freq_dist.most_common(50)
# Out:
# [('@realDonaldTrump', 2997),
#  ('@POTUS', 345),
#  ('@21WIRE', 283),
#  ('@FoxNews', 233),
#  ('@HillaryClinton', 198),
#  ('@seanhannity', 176),
#  ('@CNN', 170),
#  ('@nytimes', 126),
#  ('@foxandfriends', 101),
#  ('@elizabethforma', 98),
#  ('@NBCNews', 93),
#  ('@JordanUhl', 87),
#  ('@tonyposnanski', 86),
#  ('@ABC', 81),
#  ('@AnnCoulter', 71),
#  ('@bessbell', 69),
#  ('@PressSec', 66),
#  ('@FLOTUS', 65),
#  ('@IvankaTrump', 59),
#  ('@WalshFreedom', 53),
#  ('@WhiteHouse', 52),
#  ('@BernieSanders', 52),
#  ('@KellyannePolls', 51),
#  ('@PrisonPlanet', 49),
#  ('@BraddJaffy', 49),
#  ('@SpeakerRyan', 48),
#  ('@realdonaldtrump', 48),
#  ('@DonaldJTrumpJr', 47),
#  ('@marcorubio', 46),
#  ('@SarahPalinUSA', 45),
#  ('@ABCPolitics', 44),
#  ('@BarackObama', 43),
#  ('@CNNPolitics', 39),
#  ('@EricTrump', 39),
#  ('@MSNBC', 39),
#  ('@Morning_Joe', 39),
#  ('@joshdcaplan', 39),
#  ('@GOP', 38),
#  ('@CBSNews', 38),
#  ('@JackPosobiec', 38),
#  ('@Cernovich', 37),
#  ('@kylegriffin1', 36),
#  ('@mike_pence', 36),
#  ('@MatthewDicks', 36),
#  ('@tedcruz', 36),
#  ('@wikileaks', 35),
#  ('@pattonoswalt', 35),
#  ('@Green_Footballs', 34),
#  ('@VP', 34),
#  ('@laurenduca', 34)]

# %%
# total number of Twitter handles
len(twitter_handles)
# Out:
# 22224

# %%
df['clean_text'] = df['clean_text'].apply(lambda x: re.sub(TWITTER_HANDLE_REGEX, '@twitter-handle', x))

# %%
df.head()
# Out:
#    Unnamed: 0                                              title  \
# 0           0   Donald Trump Sends Out Embarrassing New Year’...
# 1           1   Drunk Bragging Trump Staffer Started Russian ...
# 2           2   Sheriff David Clarke Becomes An Internet Joke...
# 3           3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4           4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject        date  \
# 0  Donald Trump just couldn t wish all Americans ...    News  2017-12-31
# 1  House Intelligence Committee Chairman Devin Nu...    News  2017-12-31
# 2  On Friday, it was revealed that former Milwauk...    News  2017-12-30
# 3  On Christmas day, Donald Trump announced that ...    News  2017-12-29
# 4  Pope Francis used his annual Christmas Day mes...    News  2017-12-25
#
#   label  caps_in_title                                        text_tokens  \
# 0  fake             11  [Donald, Trump, just, couldn, t, wish, all, Am...
# 1  fake              8  [House, Intelligence, Committee, Chairman, Dev...
# 2  fake             15  [On, Friday, it, was, revealed, that, former, ...
# 3  fake             19  [On, Christmas, day, Donald, Trump, announced,...
# 4  fake             11  [Pope, Francis, used, his, annual, Christmas, ...
#
#                                            text_urls  \
# 0                       [pic.twitter.com/4FPAe2KypA]
# 1                                                 []
# 2  [pic.twitter.com/XtZW5PdU2b, pic.twitter.com/T...
# 3  [https://t.co/Fg7VacxRtJ, pic.twitter.com/5gEM...
# 4                                                 []
#
#                                           clean_text title_urls  \
# 0  Donald Trump just couldn t wish all Americans ...         []
# 1  House Intelligence Committee Chairman Devin Nu...         []
# 2  On Friday, it was revealed that former Milwauk...         []
# 3  On Christmas day, Donald Trump announced that ...         []
# 4  Pope Francis used his annual Christmas Day mes...         []
#
#                                      twitter_handles
# 0  [@realDonaldTrump, @TalbertSwan, @calvinstowel...
# 1                                                 []
# 2  [@SheriffClarke, @SheriffClarke, @KeithLeBlanc...
# 3  [@pbump, @_cingraham, @_cingraham, @_cingraham...
# 4                                                 []

# %% [markdown]
# #### Capitalization

# %%
def lower_unless_all_caps(string_):
    """
    Make all words in the input string lowercase unless that 
    word is in all caps
    """
    words = string_.split()
    processed_words = [w.lower() if not (w.isupper() and len(w) > 1) else w for w in words]
    return ' '.join(processed_words)

# %%
df['clean_text'] = df['clean_text'].apply(lower_unless_all_caps)

# %%
df['clean_title'] = df['title'].apply(lower_unless_all_caps)

# %%
df.head()
# Out:
#    Unnamed: 0                                              title  \
# 0           0   Donald Trump Sends Out Embarrassing New Year’...
# 1           1   Drunk Bragging Trump Staffer Started Russian ...
# 2           2   Sheriff David Clarke Becomes An Internet Joke...
# 3           3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4           4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject        date  \
# 0  Donald Trump just couldn t wish all Americans ...    News  2017-12-31
# 1  House Intelligence Committee Chairman Devin Nu...    News  2017-12-31
# 2  On Friday, it was revealed that former Milwauk...    News  2017-12-30
# 3  On Christmas day, Donald Trump announced that ...    News  2017-12-29
# 4  Pope Francis used his annual Christmas Day mes...    News  2017-12-25
#
#   label  caps_in_title                                        text_tokens  \
# 0  fake             11  [Donald, Trump, just, couldn, t, wish, all, Am...
# 1  fake              8  [House, Intelligence, Committee, Chairman, Dev...
# 2  fake             15  [On, Friday, it, was, revealed, that, former, ...
# 3  fake             19  [On, Christmas, day, Donald, Trump, announced,...
# 4  fake             11  [Pope, Francis, used, his, annual, Christmas, ...
#
#                                            text_urls  \
# 0                       [pic.twitter.com/4FPAe2KypA]
# 1                                                 []
# 2  [pic.twitter.com/XtZW5PdU2b, pic.twitter.com/T...
# 3  [https://t.co/Fg7VacxRtJ, pic.twitter.com/5gEM...
# 4                                                 []
#
#                                           clean_text title_urls  \
# 0  donald trump just couldn t wish all americans ...         []
# 1  house intelligence committee chairman devin nu...         []
# 2  on friday, it was revealed that former milwauk...         []
# 3  on christmas day, donald trump announced that ...         []
# 4  pope francis used his annual christmas day mes...         []
#
#                                      twitter_handles  \
# 0  [@realDonaldTrump, @TalbertSwan, @calvinstowel...
# 1                                                 []
# 2  [@SheriffClarke, @SheriffClarke, @KeithLeBlanc...
# 3  [@pbump, @_cingraham, @_cingraham, @_cingraham...
# 4                                                 []
#
#                                          clean_title
# 0  donald trump sends out embarrassing new year’s...
# 1  drunk bragging trump staffer started russian c...
# 2  sheriff david clarke becomes an internet joke ...
# 3  trump is so obsessed he even has obama’s name ...
# 4  pope francis just called out donald trump duri...

# %% [markdown]
# #### Numbers

# %% [markdown]
# The only number/date that is important is 9/11 so we will change it to nine-eleven so that numbers can more easily be removed.
# Also, we will replace the numbers with a space because some of the sentences run together and end with a number. Replacing the number with a space will split the sentences.

# %%
df['clean_text'] = df['clean_text'].apply(lambda x: re.sub(r'9\/11', 'nine-eleven', x))

# %%
df['clean_title'] = df['clean_title'].apply(lambda x: re.sub(r'9\/11', 'nine-eleven', x))

# %%
df['clean_text'] = df['clean_text'].apply(lambda x: re.sub(r'\d+', ' ', x))

# %%
df['clean_title'] = df['clean_title'].apply(lambda x: re.sub(r'\d+', ' ', x))

# %% [markdown]
# #### Rough Look at the tokens from the current clean_text

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\konst\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
df['clean_text_tokens'] = df['clean_text'].apply(word_tokenize)

# %%
review_freq_dis(df, 'clean_text_tokens', 150)
# Out:
# The number of unique tokens in the corpus is 201119
# [('the', 859850),
#  (',', 779608),
#  ('.', 545038),
#  ('to', 458899),
#  ('of', 373564),
#  ('a', 352458),
#  ('and', 345523),
#  ('in', 297929),
#  ('that', 203739),
#  ('s', 199176),
#  ('on', 166851),
#  ('for', 147198),
#  ('is', 139896),
#  ('said', 120761),
#  ('trump', 117664),
#  ('he', 117178),
#  ('it', 110546),
#  ('with', 100697),
#  ('was', 96714),
#  ('as', 88050),
#  ('his', 84136),
#  ('by', 80892),
#  ('has', 78137),
#  ('not', 72455),
#  ('be', 71205),
#  ('have', 71038),
#  ('’', 70279),
#  ('from', 68567),
#  (')', 68006),
#  ('(', 67765),
#  ('this', 62810),
#  ('at', 62594),
#  ('are', 61005),
#  ('who', 58866),
#  ('an', 57936),
#  ('they', 57188),
#  ('“', 53766),
#  ('”', 53489),
#  ('but', 50924),
#  ('we', 50799),
#  (':', 49644),
#  ('would', 49324),
#  ('i', 46703),
#  ('president', 45340),
#  ('U.S.', 43292),
#  ('will', 43158),
#  ('about', 42409),
#  ('t', 40472),
#  ('had', 40273),
#  ('their', 39205),
#  ('you', 37857),
#  ('been', 36559),
#  ('people', 35603),
#  ('-', 34196),
#  ('were', 34161),
#  ('which', 33413),
#  ('or', 33116),
#  ('more', 32885),
#  ('after', 31622),
#  ('she', 30883),
#  ('one', 30122),
#  ('if', 30087),
#  ('her', 29022),
#  ('state', 28335),
#  ('out', 28327),
#  ('reuters', 28290),
#  ('all', 27998),
#  ('what', 27420),
#  ('its', 27295),
#  ('also', 26968),
#  ('when', 26685),
#  ('there', 26101),
#  ('new', 25891),
#  ('can', 25495),
#  ('donald', 25322),
#  ('@', 24999),
#  ('up', 24822),
#  ('no', 24383),
#  ('house', 24301),
#  ('over', 24099),
#  ('government', 23847),
#  ('states', 23375),
#  ('?', 23146),
#  ('republican', 22958),
#  ('clinton', 22105),
#  ('twitter-handle', 21923),
#  ('him', 21839),
#  ('obama', 21824),
#  ('than', 21775),
#  ('our', 21726),
#  ('some', 21305),
#  ('could', 21248),
#  ('so', 21225),
#  ('other', 21198),
#  ('united', 20987),
#  ('just', 20846),
#  ('told', 20639),
#  ('into', 19381),
#  ('white', 19267),
#  ('against', 18885),
#  ('do', 18880),
#  ('campaign', 18856),
#  ('because', 18755),
#  ('like', 18479),
#  ('last', 18156),
#  ('them', 18018),
#  ('party', 17960),
#  ('two', 17517),
#  ('any', 17486),
#  ('election', 17370),
#  ('$', 16678),
#  ('now', 16550),
#  ('time', 16535),
#  ('only', 15917),
#  ('first', 15831),
#  ('former', 15623),
#  ('year', 15584),
#  ('how', 15513),
#  ('country', 15270),
#  ('news', 15122),
#  ('even', 14959),
#  ('should', 14926),
#  ('while', 14578),
#  ('did', 14568),
#  ('being', 14407),
#  ('!', 14258),
#  ('before', 13989),
#  ('many', 13909),
#  ('during', 13898),
#  ('years', 13762),
#  ('security', 13618),
#  ('may', 13404),
#  ('say', 13369),
#  ('most', 13362),
#  ('percent', 13184),
#  ('republicans', 13070),
#  ('national', 13049),
#  ('court', 12974),
#  ('since', 12788),
#  ('political', 12709),
#  ('made', 12708),
#  ('law', 12608),
#  ('those', 12601),
#  ('get', 12526),
#  ('make', 12488),
#  ('presidential', 12340),
#  ('hillary', 12325),
#  ('going', 12228),
#  ('where', 12036),
#  ('administration', 11976)]

# %% [markdown]
# #### Remove (reuters) from news stories

# %% [markdown]
# Almost all the True news stories have (Reuters) at their beginning and a ML model would merely learn that as how to distinguish Fake vs True, which would overfit potential models to this dataset.

# %%
df['clean_text'] = df['clean_text'].apply(lambda x: re.sub(r'\(reuters\)', ' ', x))

# %% [markdown]
# #### Update Tokens

# %%
df['clean_text_tokens'] = df['clean_text'].apply(word_tokenize)

# %%
review_freq_dis(df, 'clean_text_tokens', 150)
# Out:
# The number of unique tokens in the corpus is 201119
# [('the', 859850),
#  (',', 779608),
#  ('.', 545038),
#  ('to', 458899),
#  ('of', 373564),
#  ('a', 352458),
#  ('and', 345523),
#  ('in', 297929),
#  ('that', 203739),
#  ('s', 199176),
#  ('on', 166851),
#  ('for', 147198),
#  ('is', 139896),
#  ('said', 120761),
#  ('trump', 117664),
#  ('he', 117178),
#  ('it', 110546),
#  ('with', 100697),
#  ('was', 96714),
#  ('as', 88050),
#  ('his', 84136),
#  ('by', 80892),
#  ('has', 78137),
#  ('not', 72455),
#  ('be', 71205),
#  ('have', 71038),
#  ('’', 70279),
#  ('from', 68567),
#  ('this', 62810),
#  ('at', 62594),
#  ('are', 61005),
#  ('who', 58866),
#  ('an', 57936),
#  ('they', 57188),
#  ('“', 53766),
#  ('”', 53489),
#  ('but', 50924),
#  ('we', 50799),
#  (':', 49644),
#  ('would', 49324),
#  (')', 46974),
#  ('(', 46733),
#  ('i', 46703),
#  ('president', 45340),
#  ('U.S.', 43292),
#  ('will', 43158),
#  ('about', 42409),
#  ('t', 40472),
#  ('had', 40273),
#  ('their', 39205),
#  ('you', 37857),
#  ('been', 36559),
#  ('people', 35603),
#  ('-', 34196),
#  ('were', 34161),
#  ('which', 33413),
#  ('or', 33116),
#  ('more', 32885),
#  ('after', 31622),
#  ('she', 30883),
#  ('one', 30122),
#  ('if', 30087),
#  ('her', 29022),
#  ('state', 28335),
#  ('out', 28327),
#  ('all', 27998),
#  ('what', 27420),
#  ('its', 27295),
#  ('also', 26968),
#  ('when', 26685),
#  ('there', 26101),
#  ('new', 25891),
#  ('can', 25495),
#  ('donald', 25322),
#  ('@', 24999),
#  ('up', 24822),
#  ('no', 24383),
#  ('house', 24301),
#  ('over', 24099),
#  ('government', 23847),
#  ('states', 23375),
#  ('?', 23146),
#  ('republican', 22958),
#  ('clinton', 22105),
#  ('twitter-handle', 21923),
#  ('him', 21839),
#  ('obama', 21824),
#  ('than', 21775),
#  ('our', 21726),
#  ('some', 21305),
#  ('could', 21248),
#  ('so', 21225),
#  ('other', 21198),
#  ('united', 20987),
#  ('just', 20846),
#  ('told', 20639),
#  ('into', 19381),
#  ('white', 19267),
#  ('against', 18885),
#  ('do', 18880),
#  ('campaign', 18856),
#  ('because', 18755),
#  ('like', 18479),
#  ('last', 18156),
#  ('them', 18018),
#  ('party', 17960),
#  ('two', 17517),
#  ('any', 17486),
#  ('election', 17370),
#  ('$', 16678),
#  ('now', 16550),
#  ('time', 16535),
#  ('only', 15917),
#  ('first', 15831),
#  ('former', 15623),
#  ('year', 15584),
#  ('how', 15513),
#  ('country', 15270),
#  ('news', 15122),
#  ('even', 14959),
#  ('should', 14926),
#  ('while', 14578),
#  ('did', 14568),
#  ('being', 14407),
#  ('!', 14258),
#  ('before', 13989),
#  ('many', 13909),
#  ('during', 13898),
#  ('years', 13762),
#  ('security', 13618),
#  ('may', 13404),
#  ('say', 13369),
#  ('most', 13362),
#  ('percent', 13184),
#  ('republicans', 13070),
#  ('national', 13049),
#  ('court', 12974),
#  ('since', 12788),
#  ('political', 12709),
#  ('made', 12708),
#  ('law', 12608),
#  ('those', 12601),
#  ('get', 12526),
#  ('make', 12488),
#  ('presidential', 12340),
#  ('hillary', 12325),
#  ('going', 12228),
#  ('where', 12036),
#  ('administration', 11976),
#  ('under', 11940)]

# %% [markdown]
# #### Remove Punctuation and Single Letter Tokens from Text

# %% [markdown]
# We remove the Punctuation tokens except for the exclamation point. Also, we will remove all the single characters except for i.

# %%
df['clean_text_tokens'] = df['clean_text_tokens'].apply(lambda x: remove_single_characters(x, ['i', '!']))

# %%
review_freq_dis(df, 'clean_text_tokens', 150)
# Out:
# The number of unique tokens in the corpus is 201028
# [('the', 859850),
#  ('to', 458899),
#  ('of', 373564),
#  ('and', 345523),
#  ('in', 297929),
#  ('that', 203739),
#  ('on', 166851),
#  ('for', 147198),
#  ('is', 139896),
#  ('said', 120761),
#  ('trump', 117664),
#  ('he', 117178),
#  ('it', 110546),
#  ('with', 100697),
#  ('was', 96714),
#  ('as', 88050),
#  ('his', 84136),
#  ('by', 80892),
#  ('has', 78137),
#  ('not', 72455),
#  ('be', 71205),
#  ('have', 71038),
#  ('from', 68567),
#  ('this', 62810),
#  ('at', 62594),
#  ('are', 61005),
#  ('who', 58866),
#  ('an', 57936),
#  ('they', 57188),
#  ('but', 50924),
#  ('we', 50799),
#  ('would', 49324),
#  ('i', 46703),
#  ('president', 45340),
#  ('U.S.', 43292),
#  ('will', 43158),
#  ('about', 42409),
#  ('had', 40273),
#  ('their', 39205),
#  ('you', 37857),
#  ('been', 36559),
#  ('people', 35603),
#  ('were', 34161),
#  ('which', 33413),
#  ('or', 33116),
#  ('more', 32885),
#  ('after', 31622),
#  ('she', 30883),
#  ('one', 30122),
#  ('if', 30087),
#  ('her', 29022),
#  ('state', 28335),
#  ('out', 28327),
#  ('all', 27998),
#  ('what', 27420),
#  ('its', 27295),
#  ('also', 26968),
#  ('when', 26685),
#  ('there', 26101),
#  ('new', 25891),
#  ('can', 25495),
#  ('donald', 25322),
#  ('up', 24822),
#  ('no', 24383),
#  ('house', 24301),
#  ('over', 24099),
#  ('government', 23847),
#  ('states', 23375),
#  ('republican', 22958),
#  ('clinton', 22105),
#  ('twitter-handle', 21923),
#  ('him', 21839),
#  ('obama', 21824),
#  ('than', 21775),
#  ('our', 21726),
#  ('some', 21305),
#  ('could', 21248),
#  ('so', 21225),
#  ('other', 21198),
#  ('united', 20987),
#  ('just', 20846),
#  ('told', 20639),
#  ('into', 19381),
#  ('white', 19267),
#  ('against', 18885),
#  ('do', 18880),
#  ('campaign', 18856),
#  ('because', 18755),
#  ('like', 18479),
#  ('last', 18156),
#  ('them', 18018),
#  ('party', 17960),
#  ('two', 17517),
#  ('any', 17486),
#  ('election', 17370),
#  ('now', 16550),
#  ('time', 16535),
#  ('only', 15917),
#  ('first', 15831),
#  ('former', 15623),
#  ('year', 15584),
#  ('how', 15513),
#  ('country', 15270),
#  ('news', 15122),
#  ('even', 14959),
#  ('should', 14926),
#  ('while', 14578),
#  ('did', 14568),
#  ('being', 14407),
#  ('!', 14258),
#  ('before', 13989),
#  ('many', 13909),
#  ('during', 13898),
#  ('years', 13762),
#  ('security', 13618),
#  ('may', 13404),
#  ('say', 13369),
#  ('most', 13362),
#  ('percent', 13184),
#  ('republicans', 13070),
#  ('national', 13049),
#  ('court', 12974),
#  ('since', 12788),
#  ('political', 12709),
#  ('made', 12708),
#  ('law', 12608),
#  ('those', 12601),
#  ('get', 12526),
#  ('make', 12488),
#  ('presidential', 12340),
#  ('hillary', 12325),
#  ('going', 12228),
#  ('where', 12036),
#  ('administration', 11976),
#  ('under', 11940),
#  ('re', 11835),
#  ('senate', 11779),
#  ('media', 11755),
#  ('police', 11747),
#  ('very', 11659),
#  ('russia', 11648),
#  ('democratic', 11618),
#  ('north', 11513),
#  ('american', 11417),
#  ('support', 11393),
#  ('week', 11332),
#  ('bill', 11328),
#  ('back', 11189),
#  ('including', 11134),
#  ('vote', 11085)]

# %% [markdown]
# #### Tokenize Clean Title

# %%
df['clean_title_tokens'] = df['clean_title'].apply(word_tokenize)

# %%
df.iloc[1000:1010]['clean_title_tokens']
# Out:
# 1000    [stunning, new, poll, reveals, global, opinion...
# 1001    [former, GOP, rep, throws, support, behind, ob...
# 1002    [trump, moronically, claims, entire, russia, i...
# 1003    [WATCH, :, it, just, hit, a, trump, supporter,...
# 1004    [republicans, just, added, what, they, hated, ...
# 1005    [the, numbers, are, in, and, jon, ossoff, losi...
# 1006    [GOP, senator, lashes, into, kellyanne, conway...
# 1007    [cops, in, republican, senate, office, violent...
# 1008    [trump, is, giddy, about, his, upcoming, meeti...
# 1009    [catholic, sister, rips, ‘, pro-life, ’, repub...
# Name: clean_title_tokens, dtype: object

# %%
review_freq_dis(df, 'clean_title_tokens', 150)
# Out:
# The number of unique tokens in the corpus is 31502
# [('to', 14060),
#  ('trump', 11939),
#  (':', 10879),
#  ('’', 10184),
#  (',', 8742),
#  ('in', 7536),
#  ('of', 6083),
#  ('for', 6043),
#  ('on', 5630),
#  ('the', 4638),
#  ('s', 4576),
#  ('U.S.', 4157),
#  ("'s", 4120),
#  ('(', 4101),
#  (')', 4101),
#  ('VIDEO', 3992),
#  ('says', 3347),
#  ('a', 3273),
#  ('with', 3134),
#  ('”', 3080),
#  ('[', 3035),
#  (']', 3034),
#  ('and', 2943),
#  ('“', 2847),
#  ('‘', 2838),
#  ("'", 2619),
#  ('is', 2263),
#  ('!', 2157),
#  ('after', 2114),
#  ('video', 1957),
#  ('obama', 1807),
#  ('house', 1794),
#  ('at', 1774),
#  ('as', 1763),
#  ('over', 1694),
#  ('from', 1551),
#  ('he', 1533),
#  ('his', 1528),
#  ('by', 1484),
#  ('about', 1455),
#  ('white', 1377),
#  ('new', 1368),
#  ('it', 1356),
#  ('will', 1312),
#  ('not', 1309),
#  ('WATCH', 1267),
#  ('clinton', 1202),
#  ('?', 1174),
#  ('russia', 1142),
#  ('just', 1133),
#  ('t', 1125),
#  ('be', 1122),
#  ('president', 1117),
#  ('hillary', 1059),
#  ('bill', 1027),
#  ('republican', 992),
#  ('north', 986),
#  ('korea', 912),
#  ('that', 890),
#  ('this', 888),
#  ('*', 881),
#  ('senate', 878),
#  ('out', 876),
#  ('state', 868),
#  ('court', 863),
#  ('china', 796),
#  ('who', 788),
#  ('him', 785),
#  ('against', 782),
#  ('S', 780),
#  ('up', 775),
#  ('election', 763),
#  ('you', 760),
#  ('are', 758),
#  ('has', 752),
#  ('vote', 744),
#  ('donald', 723),
#  ('republicans', 720),
#  ('tax', 711),
#  ('calls', 695),
#  ('GOP', 694),
#  ('may', 670),
#  ('.', 664),
#  ('her', 653),
#  ('was', 647),
#  ('campaign', 633),
#  ('deal', 630),
#  ('TRUMP', 628),
#  ('no', 625),
#  ('news', 594),
#  ('more', 594),
#  ('police', 585),
#  ('$', 579),
#  ('iran', 576),
#  ('have', 553),
#  ('BREAKING', 552),
#  ('media', 551),
#  ('if', 544),
#  ('THE', 538),
#  ('russian', 537),
#  ('talks', 533),
#  ('what', 521),
#  ('party', 518),
#  ('how', 517),
#  ('gets', 516),
#  ('government', 516),
#  ('black', 512),
#  ('they', 508),
#  ('syria', 508),
#  ('EU', 507),
#  ('–', 503),
#  ('can', 502),
#  ('leader', 482),
#  ('minister', 477),
#  ('twitter', 475),
#  ('plan', 474),
#  ('down', 474),
#  ('#', 474),
#  ('attack', 471),
#  ('OBAMA', 465),
#  ('TO', 463),
#  ('one', 462),
#  ('people', 461),
#  ('democrats', 460),
#  ('U.N.', 457),
#  ('congress', 450),
#  ('why', 446),
#  ('south', 445),
#  ('TWEETS', 443),
#  ('PM', 443),
#  ('chief', 442),
#  ('top', 440),
#  ('OF', 439),
#  ('into', 431),
#  ('FBI', 429),
#  ('security', 426),
#  ('ban', 425),
#  ('former', 424),
#  ('back', 423),
#  ('senator', 423),
#  ('first', 419),
#  ('law', 416),
#  ('but', 415),
#  ('we', 412),
#  ('factbox', 411),
#  ('would', 410),
#  ('probe', 410),
#  ('official', 406),
#  ('-', 404),
#  ('brexit', 403)]

# %% [markdown]
# #### Remove Punctuation and Single Letter Tokens from Clean Title

# %%
df['clean_title_tokens'] = df['clean_title_tokens'].apply(lambda x: remove_single_characters(x, ['i', '!']))

# %%
review_freq_dis(df, 'clean_title_tokens', 150)
# Out:
# The number of unique tokens in the corpus is 31424
# [('to', 14060),
#  ('trump', 11939),
#  ('in', 7536),
#  ('of', 6083),
#  ('for', 6043),
#  ('on', 5630),
#  ('the', 4638),
#  ('U.S.', 4157),
#  ("'s", 4120),
#  ('VIDEO', 3992),
#  ('says', 3347),
#  ('with', 3134),
#  ('and', 2943),
#  ('is', 2263),
#  ('!', 2157),
#  ('after', 2114),
#  ('video', 1957),
#  ('obama', 1807),
#  ('house', 1794),
#  ('at', 1774),
#  ('as', 1763),
#  ('over', 1694),
#  ('from', 1551),
#  ('he', 1533),
#  ('his', 1528),
#  ('by', 1484),
#  ('about', 1455),
#  ('white', 1377),
#  ('new', 1368),
#  ('it', 1356),
#  ('will', 1312),
#  ('not', 1309),
#  ('WATCH', 1267),
#  ('clinton', 1202),
#  ('russia', 1142),
#  ('just', 1133),
#  ('be', 1122),
#  ('president', 1117),
#  ('hillary', 1059),
#  ('bill', 1027),
#  ('republican', 992),
#  ('north', 986),
#  ('korea', 912),
#  ('that', 890),
#  ('this', 888),
#  ('senate', 878),
#  ('out', 876),
#  ('state', 868),
#  ('court', 863),
#  ('china', 796),
#  ('who', 788),
#  ('him', 785),
#  ('against', 782),
#  ('up', 775),
#  ('election', 763),
#  ('you', 760),
#  ('are', 758),
#  ('has', 752),
#  ('vote', 744),
#  ('donald', 723),
#  ('republicans', 720),
#  ('tax', 711),
#  ('calls', 695),
#  ('GOP', 694),
#  ('may', 670),
#  ('her', 653),
#  ('was', 647),
#  ('campaign', 633),
#  ('deal', 630),
#  ('TRUMP', 628),
#  ('no', 625),
#  ('news', 594),
#  ('more', 594),
#  ('police', 585),
#  ('iran', 576),
#  ('have', 553),
#  ('BREAKING', 552),
#  ('media', 551),
#  ('if', 544),
#  ('THE', 538),
#  ('russian', 537),
#  ('talks', 533),
#  ('what', 521),
#  ('party', 518),
#  ('how', 517),
#  ('gets', 516),
#  ('government', 516),
#  ('black', 512),
#  ('they', 508),
#  ('syria', 508),
#  ('EU', 507),
#  ('can', 502),
#  ('leader', 482),
#  ('minister', 477),
#  ('twitter', 475),
#  ('plan', 474),
#  ('down', 474),
#  ('attack', 471),
#  ('OBAMA', 465),
#  ('TO', 463),
#  ('one', 462),
#  ('people', 461),
#  ('democrats', 460),
#  ('U.N.', 457),
#  ('congress', 450),
#  ('why', 446),
#  ('south', 445),
#  ('TWEETS', 443),
#  ('PM', 443),
#  ('chief', 442),
#  ('top', 440),
#  ('OF', 439),
#  ('into', 431),
#  ('FBI', 429),
#  ('security', 426),
#  ('ban', 425),
#  ('former', 424),
#  ('back', 423),
#  ('senator', 423),
#  ('first', 419),
#  ('law', 416),
#  ('but', 415),
#  ('we', 412),
#  ('factbox', 411),
#  ('would', 410),
#  ('probe', 410),
#  ('official', 406),
#  ('brexit', 403),
#  ('america', 402),
#  ('governor', 400),
#  ('HILLARY', 396),
#  ('their', 395),
#  ('during', 393),
#  ('war', 392),
#  ('tells', 390),
#  ('off', 388),
#  ('could', 384),
#  ('military', 384),
#  ('CNN', 383),
#  ('she', 381),
#  ('turkey', 372),
#  ('cruz', 369),
#  ('should', 367),
#  ('all', 364),
#  ('nuclear', 363),
#  ('an', 362),
#  ('speech', 361),
#  ('make', 361),
#  ('sanctions', 354),
#  ('putin', 353)]

# %% [markdown]
# #### Remove 's

# %% [markdown]
# While the fake news frequently or always didn't removed the apostrophe from 's, it doesn't look like that was done to the true news. 's will need to be removed so that it doesn't become a false indicator of true news.

# %%
df['clean_title_tokens'] = df['clean_title_tokens'].apply(lambda x: remove_words(x, ["'s"]))
df['clean_text_tokens'] = df['clean_text_tokens'].apply(lambda x: remove_words(x, ["'s"]))

# %% [markdown]
# #### Remove Date Words

# %%
date_words = ['monday', 'tuesday', 'wednesday', 'thursday', 'friday', 
              'saturday', 'sunday', 'january', 'february', 'march', 'april',
             'may', 'june', 'july', 'august', 'september', 'october',
             'november', 'december']

# %%
df['clean_title_tokens'] = df['clean_title_tokens'].apply(lambda x: remove_words(x, date_words))
df['clean_text_tokens'] = df['clean_text_tokens'].apply(lambda x: remove_words(x, date_words))

# %%
df.to_csv('text_pre_processing.csv')
