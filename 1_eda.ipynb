# %%
#import libraries 
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from google.colab import drive 
from oauth2client.client import GoogleCredentials
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# **Load Data**

# %%
fake_df = pd.read_csv('/content/gdrive/MyDrive/Fake.csv')
fake_df
# Out:
#                                                    title  ...               date
# 0       Donald Trump Sends Out Embarrassing New Year’...  ...  December 31, 2017
# 1       Drunk Bragging Trump Staffer Started Russian ...  ...  December 31, 2017
# 2       Sheriff David Clarke Becomes An Internet Joke...  ...  December 30, 2017
# 3       Trump Is So Obsessed He Even Has Obama’s Name...  ...  December 29, 2017
# 4       Pope Francis Just Called Out Donald Trump Dur...  ...  December 25, 2017
# ...                                                  ...  ...                ...
# 23476  McPain: John McCain Furious That Iran Treated ...  ...   January 16, 2016
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...  ...   January 16, 2016
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...  ...   January 15, 2016
# 23479  How to Blow $700 Million: Al Jazeera America F...  ...   January 14, 2016
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...  ...   January 12, 2016
#
# [23481 rows x 4 columns]

# %%
true_df = pd.read_csv('/content/gdrive/MyDrive/True.csv')
true_df
# Out:
#                                                    title  ...                date
# 0      As U.S. budget fight looms, Republicans flip t...  ...  December 31, 2017
# 1      U.S. military to accept transgender recruits o...  ...  December 29, 2017
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...  ...  December 31, 2017
# 3      FBI Russia probe helped by Australian diplomat...  ...  December 30, 2017
# 4      Trump wants Postal Service to charge 'much mor...  ...  December 29, 2017
# ...                                                  ...  ...                 ...
# 21412  'Fully committed' NATO backs new U.S. approach...  ...    August 22, 2017
# 21413  LexisNexis withdrew two products from Chinese ...  ...    August 22, 2017
# 21414  Minsk cultural hub becomes haven from authorities  ...    August 22, 2017
# 21415  Vatican upbeat on possibility of Pope Francis ...  ...    August 22, 2017
# 21416  Indonesia to buy $1.14 billion worth of Russia...  ...    August 22, 2017
#
# [21417 rows x 4 columns]

# %%
true_df['label'] = 'true'

# %%
fake_df['label'] = 'fake'

# %%
#merge the fake and true data frames
df = pd.concat([fake_df, true_df], ignore_index=True)

# %%
df.head()
# Out:
#                                                title  ... label
# 0   Donald Trump Sends Out Embarrassing New Year’...  ...  fake
# 1   Drunk Bragging Trump Staffer Started Russian ...  ...  fake
# 2   Sheriff David Clarke Becomes An Internet Joke...  ...  fake
# 3   Trump Is So Obsessed He Even Has Obama’s Name...  ...  fake
# 4   Pope Francis Just Called Out Donald Trump Dur...  ...  fake
#
# [5 rows x 5 columns]

# %% [markdown]
# # Clean the Data

# %% [markdown]
# **1. Check for missing values**

# %%
df.info() #no missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44898 entries, 0 to 44897
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    44898 non-null  object
#  1   text     44898 non-null  object
#  2   subject  44898 non-null  object
#  3   date     44898 non-null  object
#  4   label    44898 non-null  object
# dtypes: object(5)
# memory usage: 1.7+ MB

# %% [markdown]
# **2. Dublicate Values**

# %%
#title column
title_value_counts = df.title.value_counts()

# %%
title_value_counts[title_value_counts > 1]
# Out:
# Factbox: Trump fills top jobs for his administration                                                                                                          14
# Factbox: Contenders for senior jobs in Trump's administration                                                                                                  8
# Highlights: The Trump presidency on April 13 at 9:30 P.M. EDT/0130 GMT on Friday                                                                               8
# MEDIA IGNORES Time That Bill Clinton FIRED His FBI Director On Day Before Vince Foster Was Found Dead                                                          6
# Factbox: International reaction to arrest of Reuters reporters in Myanmar                                                                                      6
#                                                                                                                                                               ..
# AUSTRIA’S NOT PLAYING GAMES: Bans Face-Concealing Islamic Dress…Mandates “Integration” Course…Or Else                                                          2
# HOW COLLEGES ARE DESTROYING Free Speech: “Emergency counseling sessions” Offered After “TRUMP” Word Was Written On Sidewalk In Chalk                           2
# LEFTIST ACTRESS ALYSSA MILANO Gets BLASTED On Twitter For Calling President Trump’s “National Prayer Day” For TX Hurricane Victims: “National A**hole Day”     2
# ERIC HOLDER Encourages DOJ To Keep Attacking Trump…STUNNING List Of Holder Scandals Reveals Why Trump Needs To Drain Obama’s Corrupt DOJ Swamp                 2
# CELEBRITY CRUISE LINE CEO Makes Political Statement With Stunning Open-Borders, Trump Bashing Ad [VIDEO]                                                       2
# Name: title, Length: 5629, dtype: int64

# %% [markdown]
# There are a lot of titles that are used more than once. This will need to be reviewed.

# %%
df[df.title == 'Factbox: Trump fills top jobs for his administration']
# Out:
#                                                    title  ... label
# 29701  Factbox: Trump fills top jobs for his administ...  ...  true
# 29875  Factbox: Trump fills top jobs for his administ...  ...  true
# 30096  Factbox: Trump fills top jobs for his administ...  ...  true
# 30118  Factbox: Trump fills top jobs for his administ...  ...  true
# 30136  Factbox: Trump fills top jobs for his administ...  ...  true
# 30167  Factbox: Trump fills top jobs for his administ...  ...  true
# 30186  Factbox: Trump fills top jobs for his administ...  ...  true
# 30220  Factbox: Trump fills top jobs for his administ...  ...  true
# 30236  Factbox: Trump fills top jobs for his administ...  ...  true
# 30289  Factbox: Trump fills top jobs for his administ...  ...  true
# 30330  Factbox: Trump fills top jobs for his administ...  ...  true
# 30380  Factbox: Trump fills top jobs for his administ...  ...  true
# 30480  Factbox: Trump fills top jobs for his administ...  ...  true
# 30489  Factbox: Trump fills top jobs for his administ...  ...  true
#
# [14 rows x 5 columns]

# %%
duplicate_title_list = set(title_value_counts[title_value_counts > 1].keys())

# %%
df_dup_titles = df[df.title.isin(duplicate_title_list)]

# %%
df_dup_titles
# Out:
#                                                    title  ... label
# 1488    McConnell Says He’ll Obstruct ANY Effort To H...  ...  fake
# 1535    McConnell Says He’ll Obstruct ANY Effort To H...  ...  fake
# 9087   BARBRA STREISAND Gives Up On Dream Of Impeachi...  ...  fake
# 9088   WATCH: SENATOR LINDSEY GRAHAM DROPS BOMBSHELL…...  ...  fake
# 9089   “CONSERVATIVE GAY GUY” BLASTS Pence’s Aspen Ne...  ...  fake
# ...                                                  ...  ...   ...
# 44884  U.S. puts more pressure on Pakistan to help wi...  ...  true
# 44886  Trump talks tough on Pakistan's 'terrorist' ha...  ...  true
# 44887  U.S., North Korea clash at U.N. forum over nuc...  ...  true
# 44889  U.S., North Korea clash at U.N. forum over nuc...  ...  true
# 44893  'Fully committed' NATO backs new U.S. approach...  ...  true
#
# [11798 rows x 5 columns]

# %%
df_dup_titles[df_dup_titles.duplicated()]
# Out:
#                                                    title  ... label
# 9942   HILLARY TWEETS MESSAGE In Defense Of DACA…OOPS...  ...  fake
# 11446  FORMER DEMOCRAT WARNS Young Americans: “Rioter...  ...  fake
# 14925  [VIDEO] #BlackLivesMatter Terrorists Storm Dar...  ...  fake
# 23926  Senate tax bill stalls on deficit-focused 'tri...  ...  true
# 24259  Trump warns 'rogue regime' North Korea of grav...  ...  true
# ...                                                  ...  ...   ...
# 44709  France unveils labor reforms in first step to ...  ...  true
# 44744  Guatemala top court sides with U.N. graft unit...  ...  true
# 44771  Europeans, Africans agree renewed push to tack...  ...  true
# 44834  Thailand's ousted PM Yingluck has fled abroad:...  ...  true
# 44889  U.S., North Korea clash at U.N. forum over nuc...  ...  true
#
# [209 rows x 5 columns]

# %%
df_dup_titles[df_dup_titles.duplicated(['text'])]
# Out:
#                                                    title  ... label
# 9114   WHY THIS BLUE-COLLAR DEMOCRAT STRONGHOLD Count...  ...  fake
# 9738   LEFTIST STORE OWNER Makes Video Asking Libs To...  ...  fake
# 9942   HILLARY TWEETS MESSAGE In Defense Of DACA…OOPS...  ...  fake
# 11041  Joe Scarborough BERATES Mika Brzezinski Over “...  ...  fake
# 11190  WATCH TUCKER CARLSON Scorch Sanctuary City May...  ...  fake
# ...                                                  ...  ...   ...
# 44709  France unveils labor reforms in first step to ...  ...  true
# 44744  Guatemala top court sides with U.N. graft unit...  ...  true
# 44771  Europeans, Africans agree renewed push to tack...  ...  true
# 44834  Thailand's ousted PM Yingluck has fled abroad:...  ...  true
# 44889  U.S., North Korea clash at U.N. forum over nuc...  ...  true
#
# [5964 rows x 5 columns]

# %%
#Check for rows that have duplicate title and text
df_dup_titles[df_dup_titles.duplicated(['title', 'text'])]
# Out:
#                                                    title  ... label
# 9942   HILLARY TWEETS MESSAGE In Defense Of DACA…OOPS...  ...  fake
# 11446  FORMER DEMOCRAT WARNS Young Americans: “Rioter...  ...  fake
# 14925  [VIDEO] #BlackLivesMatter Terrorists Storm Dar...  ...  fake
# 15892  HOUSE INTEL Slaps Subpoenas on McCain Institut...  ...  fake
# 15893  PRICELESS! WATCH MSNBC HOST’S Shocked Response...  ...  fake
# ...                                                  ...  ...   ...
# 44709  France unveils labor reforms in first step to ...  ...  true
# 44744  Guatemala top court sides with U.N. graft unit...  ...  true
# 44771  Europeans, Africans agree renewed push to tack...  ...  true
# 44834  Thailand's ousted PM Yingluck has fled abroad:...  ...  true
# 44889  U.S., North Korea clash at U.N. forum over nuc...  ...  true
#
# [5793 rows x 5 columns]

# %% [markdown]
# There are 5793 rows with duplicate title and text.

# %%
df_dup_titles[df_dup_titles.text == ' '] #check for a text value with one space
# Out:
#                                                    title  ... label
# 10923  TAKE OUR POLL: Who Do You Think President Trum...  ...  fake
# 11041  Joe Scarborough BERATES Mika Brzezinski Over “...  ...  fake
# 11190  WATCH TUCKER CARLSON Scorch Sanctuary City May...  ...  fake
# 11236  SHOCKER: Public School Turns Computer Lab Into...  ...  fake
# 11247  MICHAEL FLYNN’S LAWYER Releases Statement Scor...  ...  fake
# ...                                                  ...  ...   ...
# 21816  BALTIMORE BURNS: MARYLAND GOVERNOR BRINGS IN N...  ...  fake
# 21826  FULL VIDEO: THE BLOCKBUSTER INVESTIGATION INTO...  ...  fake
# 21827  (VIDEO) HILLARY CLINTON: RELIGIOUS BELIEFS MUS...  ...  fake
# 21857  (VIDEO)ICE PROTECTING OBAMA: WON’T RELEASE NAM...  ...  fake
# 21873  (VIDEO) HYSTERICAL SNL TAKE ON HILLARY’S ANNOU...  ...  fake
#
# [349 rows x 5 columns]

# %%
df[df.text == ' ']
# Out:
#                                                    title  ... label
# 10923  TAKE OUR POLL: Who Do You Think President Trum...  ...  fake
# 11041  Joe Scarborough BERATES Mika Brzezinski Over “...  ...  fake
# 11190  WATCH TUCKER CARLSON Scorch Sanctuary City May...  ...  fake
# 11225  MAYOR OF SANCTUARY CITY: Trump Trying To Make ...  ...  fake
# 11236  SHOCKER: Public School Turns Computer Lab Into...  ...  fake
# ...                                                  ...  ...   ...
# 21826  FULL VIDEO: THE BLOCKBUSTER INVESTIGATION INTO...  ...  fake
# 21827  (VIDEO) HILLARY CLINTON: RELIGIOUS BELIEFS MUS...  ...  fake
# 21857  (VIDEO)ICE PROTECTING OBAMA: WON’T RELEASE NAM...  ...  fake
# 21873  (VIDEO) HYSTERICAL SNL TAKE ON HILLARY’S ANNOU...  ...  fake
# 32451                     Graphic: Supreme Court roundup  ...  true
#
# [627 rows x 5 columns]

# %%
df = df.replace(r'^\s*$', np.nan, regex=True)

# %%
df.isna().sum()
# Out:
# title        0
# text       631
# subject      0
# date         0
# label        0
# dtype: int64

# %% [markdown]
# *Remove Duplicate Data*

# %%
len(df)
# Out:
# 44898

# %%
df_clean = df.drop_duplicates(ignore_index=True)

# %%
len(df_clean)
# Out:
# 44689

# %% [markdown]
# **3. Drop Rows with No Text (just a title)**

# %%
df_clean = df_clean.dropna()

# %%
len(df_clean)
# Out:
# 44058

# %% [markdown]
# *Drop Rows with same title and text (keeping the first instance)*

# %%
df_clean = df_clean.drop_duplicates(['title', 'text'], ignore_index=True)

# %%
len(df_clean)
# Out:
# 38658

# %% [markdown]
# *Drop Rows with the same text (keeping the first instance)*

# %%
df_clean = df_clean.drop_duplicates(['text'], ignore_index=True)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38644 entries, 0 to 38643
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    38644 non-null  object
#  1   text     38644 non-null  object
#  2   subject  38644 non-null  object
#  3   date     38644 non-null  object
#  4   label    38644 non-null  object
# dtypes: object(5)
# memory usage: 1.5+ MB

# %%
len(df) - len(df_clean)
# Out:
# 6254

# %% [markdown]
# 4. Check dates

# %%
try:
    df_clean['date'] = pd.to_datetime(df_clean['date'])
except ValueError:
    print('Not all date values are dates.')
# Out:
# Not all date values are dates.

# %%
def not_a_date(string):
    """
    Check if the input string can be converted to a date.
    
    Return:
    True if it is not a date
    False if it is a date
    """
    try:
        date = pd.to_datetime(string)
        return False
    except ValueError:
        return True

# %%
df_bad_dates = df_clean[df_clean['date'].apply(not_a_date)]

# %%
df_bad_dates
# Out:
#                                                    title  ... label
# 9357   https://100percentfedup.com/served-roy-moore-v...  ...  fake
# 15119  https://100percentfedup.com/video-hillary-aske...  ...  fake
# 15120  https://100percentfedup.com/12-yr-old-black-co...  ...  fake
# 15422  https://fedup.wpengine.com/wp-content/uploads/...  ...  fake
# 15423  https://fedup.wpengine.com/wp-content/uploads/...  ...  fake
# 16126                                           Homepage  ...  fake
#
# [6 rows x 5 columns]

# %% [markdown]
# The instances with text in the date field are all invalid data and will be dropped

# %%
df_clean = df_clean.drop(df_bad_dates.index)

# %% [markdown]
# Conver dates to datetime

# %%
try:
    df_clean['date'] = pd.to_datetime(df_clean['date'])
except ValueError:
    print('Not all date values are dates.')

# %%
df_clean.date.describe()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   """Entry point for launching an IPython kernel.
# count                   38638
# unique                   1010
# top       2017-12-06 00:00:00
# freq                      177
# first     2015-03-31 00:00:00
# last      2018-02-19 00:00:00
# Name: date, dtype: object

# %%
df_early = df_clean[df_clean.date < pd.to_datetime('2016-01-01')]
df_early
# Out:
#                                                    title  ... label
# 14343  EVERY U.S. CITIZEN TAKEN HOSTAGE IN IRAN To Be...  ...  fake
# 14344  WATCH FUNNIEST MAN In American Politics Ridicu...  ...  fake
# 14345  FBI POSTS $5,000 REWARD For Person Who Committ...  ...  fake
# 14346  SWISS ARMY CHIEF WARNS CITIZENS About Explosiv...  ...  fake
# 14347  WOW! Sarah Palin’s Stunning AZ Vacation Home G...  ...  fake
# ...                                                  ...  ...   ...
# 16665  BREAKING: [Video] COLORADO BAKER WHO REFUSED T...  ...  fake
# 16666  (VIDEO) PATRIOTS DEMAND REMOVAL OF COMMUNIST FLAG  ...  fake
# 16667  BUSTED: [VIDEO] MAN ATTEMPTS TO TAPE “GOTCHA” ...  ...  fake
# 16668  [VIDEO] 16 YR OLD ARRESTED For Violent Gang Be...  ...  fake
# 16669  “Non-violence hasn’t worked”…Reverend Sam Most...  ...  fake
#
# [1597 rows x 5 columns]

# %%
df_early.label.value_counts()
# Out:
# fake    1597
# Name: label, dtype: int64

# %%
df_late = df_clean[df_clean.date > pd.to_datetime('2017-12-31')]

# %%
df_late
# Out:
#                                                   title  ... label
# 9050  Democrat Senator Warns Mueller Not To Release ...  ...  fake
# 9051  MSNBC ANCHOR Flabbergasted at What Texas Teach...  ...  fake
# 9052  WATCH: SNOWFLAKES ASKED Communist Party Platfo...  ...  fake
# 9053  JUST IN: BADASS GENERAL JOHN KELLY Shoved Chin...  ...  fake
# 9054  DOJ’s JEFF SESSIONS Opens Investigation Into W...  ...  fake
# 9055  WATCH: ’’Carpetbagger” Mitt Romney Takes Swipe...  ...  fake
# 9056  GOTCHA! A Stammering John Podesta Stunned by a...  ...  fake
# 9057  HIGH SCHOOL TEACHER Makes “Shooting At Trump” ...  ...  fake
# 9058  IT BEGINS…RINO MEGA-DONOR Threatens Jeb Bush: ...  ...  fake
# 9059  BUSTED! Maxine Waters’ Ties to Black Nationali...  ...  fake
# 9060  LOCAL REPORTER IN DEEP BLUE STATE Stuns Libera...  ...  fake
# 9061  FACEBOOK RELEASES Ads Paid For By Russians…And...  ...  fake
# 9062  FACEBOOK’S VP Of Ads BLASTS MEDIA: Majority Of...  ...  fake
# 9063  MEGHAN MCCAIN Cut-Off After Saying the Florida...  ...  fake
# 9064  BROTHER OF HERO COACH Breaks Down Over Tribute...  ...  fake
# 9065  “THE TRUMP CURSE IS REAL”…Social Media Respond...  ...  fake
# 9066  How The Left, The Anti Defamation League and M...  ...  fake
# 9067  LOOK WHO Approved Visas For Russian Operatives...  ...  fake
# 9068  JUST IN: PRESIDENT TRUMP AND FIRST LADY Make S...  ...  fake
# 9069  BREAKING: FL GOV RICK SCOTT Calls for FBI Dire...  ...  fake
# 9070  HEY, BERNIE SANDERS: 18 SCHOOL SHOOTINGS Have ...  ...  fake
# 9071  TUCKER CARLSON Rips The Left On Gun Control Hy...  ...  fake
# 9072  WATCH: Mitt Romney Announces Run for Senate…Ba...  ...  fake
# 9073  WATCH SHERIFF’S Honest Response After a School...  ...  fake
# 9074  Flashback Video: Susan Rice Says Trump’s Claim...  ...  fake
# 9075  POLITICS FIRST: LEFTIST PARENTS Of Former Comb...  ...  fake
# 9076  TWO HIGH SCHOOL JROTC Members Tell INCREDIBLE ...  ...  fake
# 9077  MEDIA PROMOTES Fake News That Shooter Connecte...  ...  fake
# 9078  WHAT’S WRONG WITH PELOSI? Nancy Stutters, Stam...  ...  fake
# 9079  “PROUD TRANSGENDER” Democrat Candidate For Con...  ...  fake
# 9080  JUST IN: Senate Rejects Immigration Bill…Trump...  ...  fake
# 9081  SC STATE REP Who is a Former Cop Proposes Smar...  ...  fake
# 9082  HUH? RAPPER JAY-Z Compares Trayvon Martin to M...  ...  fake
# 9083  The DIRTY TRUTH About DACA Recipients…Where Th...  ...  fake
# 9084  JUST IN: CROOKED DOJ OFFICIAL Didn’t Reveal Th...  ...  fake
#
# [35 rows x 5 columns]

# %%
df_clean.label.value_counts()
# Out:
# true    21191
# fake    17447
# Name: label, dtype: int64

# %% [markdown]
# There are some data out of the range of 2017-2018

# %% [markdown]
# **5. Capital Letters in Title**

# %%
df_clean['caps_in_title'] = df_clean['title'].apply(lambda title: sum(1 for char in title if char.isupper()))

# %%
df_clean
# Out:
#                                                    title  ... caps_in_title
# 0       Donald Trump Sends Out Embarrassing New Year’...  ...            11
# 1       Drunk Bragging Trump Staffer Started Russian ...  ...             8
# 2       Sheriff David Clarke Becomes An Internet Joke...  ...            15
# 3       Trump Is So Obsessed He Even Has Obama’s Name...  ...            19
# 4       Pope Francis Just Called Out Donald Trump Dur...  ...            11
# ...                                                  ...  ...           ...
# 38639  'Fully committed' NATO backs new U.S. approach...  ...             8
# 38640  LexisNexis withdrew two products from Chinese ...  ...             3
# 38641  Minsk cultural hub becomes haven from authorities  ...             1
# 38642  Vatican upbeat on possibility of Pope Francis ...  ...             4
# 38643  Indonesia to buy $1.14 billion worth of Russia...  ...             2
#
# [38638 rows x 6 columns]

# %%
df_clean.to_csv('df_clean.csv')

# %% [markdown]
# # Explore the dataset

# %%
def show_hist_for_col(df, column, title):
    """
    Display a histogram for a column in a dataframe, splitting the data by label.
    """
    plt.figure(figsize=(16,8))
    df[df.label == 'true'][column].hist(label='True')
    df[df.label == 'fake'][column].hist(alpha=0.4, label='Fake')
    plt.title(title)
    plt.legend()
    plt.show()

# %%
plt.figure(figsize=(16,8))
df_clean.label.hist()
plt.title('Fake or True News')
plt.show()

# %%
show_hist_for_col(df_clean, 'date', 'Date Range for News')

# %%
df_clean['title_len'] = df_clean.title.apply(len)

# %%
show_hist_for_col(df_clean, 'title_len', 'Number of Characters in Title')

# %%
df_clean['text_len'] = df_clean.text.apply(len)
show_hist_for_col(df_clean, 'text_len', 'Length of Text for News')

# %%
df_clean
# Out:
#                                                    title  ... text_len
# 0       Donald Trump Sends Out Embarrassing New Year’...  ...     2893
# 1       Drunk Bragging Trump Staffer Started Russian ...  ...     1898
# 2       Sheriff David Clarke Becomes An Internet Joke...  ...     3597
# 3       Trump Is So Obsessed He Even Has Obama’s Name...  ...     2774
# 4       Pope Francis Just Called Out Donald Trump Dur...  ...     2346
# ...                                                  ...  ...      ...
# 38639  'Fully committed' NATO backs new U.S. approach...  ...     2821
# 38640  LexisNexis withdrew two products from Chinese ...  ...      800
# 38641  Minsk cultural hub becomes haven from authorities  ...     1950
# 38642  Vatican upbeat on possibility of Pope Francis ...  ...     1199
# 38643  Indonesia to buy $1.14 billion worth of Russia...  ...     1338
#
# [38638 rows x 8 columns]

# %%
df_clean[['label','subject','text']].groupby(['label','subject']).count()
# Out:
#                         text
# label subject
# fake  Government News    514
#       News              9050
#       US_News            783
#       left-news          682
#       politics          6418
# true  politicsNews     11213
#       worldnews         9978

# %%
plt.figure(figsize=(10,5))
sns.countplot(x= "subject", hue = "subject", data=df_clean)

# %%
from wordcloud import WordCloud, STOPWORDS
plt.figure(figsize=(15,15))
wc=WordCloud(max_words=2000, width=1600, height=700, stopwords=STOPWORDS).generate("".join(df_clean[df_clean.label=='fake'].text))
plt.imshow(wc, interpolation="bilinear")

# %%
from wordcloud import WordCloud, STOPWORDS
plt.figure(figsize=(15,15))
wc=WordCloud(max_words=2000, width=1600, height=700, stopwords=STOPWORDS).generate("".join(df_clean[df_clean.label=='true'].text))
plt.imshow(wc, interpolation="bilinear")
